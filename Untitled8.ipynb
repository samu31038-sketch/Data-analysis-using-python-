# %% [markdown]
# <a href="https://colab.research.google.com/github/samu31038-sketch/Data-analysis-using-python-/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
