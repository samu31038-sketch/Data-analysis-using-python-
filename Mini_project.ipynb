# %% [markdown]
# <a href="https://colab.research.google.com/github/samu31038-sketch/Data-analysis-using-python-/blob/main/Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["samu", "vel", "Ravi"],
    "Sales": [500, 1500, 2500]
}

df = pd.DataFrame(data)

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd

data = {
    'emp_nm': ['samu', 'vel'],
    'emp_sal': [300, 500]
}

df = pd.DataFrame(data)

df.rename(columns={
    'emp_nm': 'Employee Name',
    'emp_sal': 'Employee Salary'
}, inplace=True)

print(df)
# Out:
#   Employee Name  Employee Salary
# 0          samu              300
# 1           vel              500

# %%
import pandas as pd

data = {
    "Region": ["South", "North", "East", "West", "West", "South", "North"],
    "Products": ["Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet", "Laptop"],
    "Sales": [6000, 6000, 7000, 8000, 9000, 10000, 11000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Region Products  Sales
# 0  South   Laptop   6000
# 1  North   Mobile   6000
# 2   East   Tablet   7000
# 3   West   Laptop   8000
# 4   West   Mobile   9000
# 5  South   Tablet  10000
# 6  North   Laptop  11000

# %%
def greet(name):
    print("Welcome", name)

greet("Glenda")
# Out:
# Welcome Glenda

# %%
import pandas as pd

data = {
    "Region": ["South", "North", "East", "West", "West", "South", "North"],
    "Products": ["Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet", "Laptop"],
    "Sales": [6000, 6000, 7000, 8000, 9000, 10000, 11000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Region Products  Sales
# 0  South   Laptop   6000
# 1  North   Mobile   6000
# 2   East   Tablet   7000
# 3   West   Laptop   8000
# 4   West   Mobile   9000
# 5  South   Tablet  10000
# 6  North   Laptop  11000

# %%
import numpy as np

marks = np.array([90, 85, 78, 92])

print(marks[2])
# Out:
# 78

# %%
import numpy as np

marks = np.array([90, 85, 78, 92])

print(marks)
# Out:
# [90 85 78 92]

# %%
try:
    num = int(input("Enter Number: "))
    print(num)

except ValueError:
    print("Invalid Input")
# Out:
# Enter Number: 35
# 35

# %%
import pandas as pd

data = pd.Series([10, 20, 30])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd

data = pd.Series(
    [100, 200, 700],
    index=["ALARM", "RADAR", "CHARGER"]
)

print(data)
# Out:
# ALARM      100
# RADAR      200
# CHARGER    700
# dtype: int64

# %%
# List of expenses
Expenses = [100, 250, 300, 150]

# Calculate total expenses
Total = sum(Expenses)

# Display the results
print("Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [100, 250, 300, 150]
# Total Expenses: 800

# %%
def greet():
    print("Hi Intership Students")

greet()
# Out:
# Hi Intership Students

# %%
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May"]
sales = [10000,12000,15000,13000,18000]
plt.plot(months,sales)
plt.title("Monthly sales")
plt.xlabel("Months")
plt.ylabel("Sales Amount")
plt.show()

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
import pandas as pd

data = {
        "Name" : ["Ihshan","Ravi","Siva"],
        "Sales": [500,1500,2500]
}
df = pd.DataFrame(data)
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd

data = {
     'emp_nm' :['Ihshan','Siva'],
     'emp_sal':[300,500],
}
df = pd.DataFrame(data)
df.rename(columns={
    'emp_nm' : 'Employee Name',
    'emp_sal': 'Employee Salary'
    }, inplace = True)
print(df)
# Out:
#   Employee Name  Employee Salary
# 0        Ihshan              300
# 1          Siva              500

# %%
import matplotlib.pyplot as plt

# Assuming you have defined your data like this:
students = ['Divya', 'Mugil', 'Munisha', 'Swetha']
marks = [85, 90, 78, 92]

plt.bar(students, marks)
plt.title("Student Marks")

# Fixed the typos here (changed xlable/ylable to xlabel/ylabel)
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()
